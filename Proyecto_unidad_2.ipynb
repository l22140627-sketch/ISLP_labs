# %% [markdown]
# <a href="https://colab.research.google.com/github/l22140627-sketch/ISLP_labs/blob/main/Proyecto_unidad_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**PASO 1**

# %% [markdown]
# **ROLES INTERNOS**
#
# **líder del equipo:** 22140635
#
# **Responsable de datos:** 22140608
#
# **Responsable de modelos:** 22140627
#
# **Responsable de documentación:** 22140141
#
# **Responsable de presentación:** 22140611
#
# **Responsable de Jira/Scrum Master:** TODOS

# %% [markdown]
# #**PASO 2**

# %% [markdown]
# Cada integrante debe leer los tres documentos adjuntos: la guía teórica
# (guia_march_mania_2026.docx), el análisis de la competencia
# (march_mania_2026_analisis.docx) y revisar la página de la competencia en
# Kaggle. Documentar dudas y conceptos clave.
# Entregables: Resumen individual de lectura. Lista de dudas para revisión con el profesor.
# Carga 1 resumen en github por cada integrante. Nombre del documento:
# Resumen[número de control].docx
